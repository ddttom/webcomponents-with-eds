// %% [markdown]
// # 📝 Unstyled Notebook Template
//
// **About this template:** This template uses pure markdown without HTML styling.
//
// **Auto-wrapping:** When displayed in **notebook mode** (`| IPynb Viewer (notebook) |`), cells are automatically wrapped with styling. In other modes (basic, paged, autorun), cells appear as plain markdown.
//
// **Use this for:**
// - Quick notebooks prioritizing speed
// - Notebook mode display
// - Content-first approach
//
// **To customize specific cells:** Add HTML wrappers with inline styles (hybrid approach).

// %% [markdown]
// # Your Notebook Title
//
// Brief description of what this notebook covers.

// %% [markdown]
// ## Table of Contents
//
// - [Section 1](#section-1)
// - [Section 2](#section-2)
// - [Section 3](#section-3)
// - [Conclusion](#conclusion)

// %% [markdown]
// ## Section 1: Introduction
//
// Your content here. Use markdown formatting:
//
// - Bullet points
// - **Bold text**
// - *Italic text*
// - `Code snippets`
//
// ### Subsection
//
// More detailed content.

// %%
// Example JavaScript code cell
const greeting = 'Hello, World!';
console.log(greeting);

return greeting;

// %% [markdown]
// ## Section 2: Main Content
//
// Explain concepts with examples.
//
// ```javascript
// // Code example in markdown (not executable)
// function example() {
//   return 'This is just for display';
// }
// ```

// %%
// Another code cell for demonstrations
const data = [1, 2, 3, 4, 5];
const sum = data.reduce((a, b) => a + b, 0);

console.log('Sum:', sum);
return sum;

// %% [markdown]
// ## Section 3: Advanced Topics
//
// More complex examples and explanations.
//
// **Key Points:**
// 1. First important point
// 2. Second important point
// 3. Third important point

// %% [markdown]
// ---
//
// This is a transition between major sections.

// %% [markdown]
// ## Conclusion
//
// ### Summary
//
// - Main takeaway 1
// - Main takeaway 2
// - Main takeaway 3
//
// ### Next Steps
//
// What to do next or where to find more information.
