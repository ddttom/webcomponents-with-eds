// %% [markdown]
// # 🗺️ [Your Documentation Title][Brief hook sentence describing what this navigation guide helps with]**Reading time: [X-Y] minutes** | **[N] cells** | **[N] parts**This guide offers multiple ways to navigate:| Part | Focus | Cells | Time ||------|-------|-------|------|| 1. [🌍 Part 1: The Big Picture](#) | Why & What | X | X min || 2. [👥Part 2: By Your Role](#) | Role-based paths | X | X min || 3. [🎯Part 3: By Your Task](#) | Task-based guides | X | X min || 4. [🔄Part 4: By Workflow](#) | Process phases | X | X min || 5. [📚Part 5: Categories](#) | Browse all | X | X min || 6. [💡Part 6: Pro Tips](#) | Expert strategies | X | X min |**Quick access:**- 🚨 [🚨 Emergency Navigation](#) - Need help NOW?- 🌟 [🌟 The Essential Three](#) - The must-reads- 🔍 [🔍 How to Search](#) - Find what you need

// %% [markdown]
// ### 🚨 Emergency Navigation - I Need Help NOW!**Skip the learning - jump straight to solutions:**| Problem | Immediate Solution ||---------|-------------------|| 🔴 **[Problem 1]** | → [solution-doc.md](path/to/doc.md) - Description || 🔴 **[Problem 2]** | → [solution-doc.md](path/to/doc.md) - Description || 🔴 **[Problem 3]** | → [solution-doc.md](path/to/doc.md) - Description || 🔴 **[Problem 4]** | → [solution-doc.md](path/to/doc.md) - Description |**For everything else:** Use the navigation below based on your role, task, or workflow phase.

// %% [markdown]
// ### 🌟 The Essential Three - Bookmark These NowEvery [user/role] should have these docs open:| Doc | Purpose | When to Use ||-----|---------|-------------|| **[index.md](path/index.md)** | Your home base | Starting point || **[core-doc.md](path/core.md)** | Your reference bible | Deep questions || **[flows.md](path/flows.md)** | Your decision trees | "Should I use X or Y?" |**Pro tip:** Keep these in browser tabs while working.

// %% [markdown]
// ### 🔍 How to Search Within Documentation**Looking for [topic 1]?**Keywords: `keyword1`, `keyword2`, `keyword3`**Need [topic 2] info?**Keywords: `keyword4`, `keyword5`, `keyword6`**Stuck with [topic 3]?**Keywords: `keyword7`, `keyword8`, `keyword9`**Pro tip:** Use your IDE's global search (Cmd/Ctrl+Shift+F) across docs directory.

// %% [markdown]
// ## 📍 What is This?[Explain what documentation system you're navigating]This notebook is your **documentation GPS** - it helps you find exactly what you need, fast.

// %% [markdown]
// ## ⚠️ Why Navigation Matters**The Documentation Crisis**[Explain the specific documentation challenges your system solves]**Living documentation solves this** through:- Executable examples that can't lie- Self-verification on every use- Multi-audience design serving everyoneThis navigator embodies those principles.

// %% [markdown]
// ### 📚 What You'll Learn- 📂 Documentation structure and organization- 🔍 How to find the right doc for your task- 🎓 Role-based learning paths- 🔄 Workflow-based navigation- 💡 Pro navigation strategies

// %% [markdown]
// ## 🌍 Part 1: The Big Picture**Progress: 1 of [N]** 🔵⚪⚪⚪⚪⚪**Reading time: X minutes**<!-- action-cards -->- [✨ Living Documentation Principles](#)- [🎯 Two Entry Points](#)- [📚 What You'll Learn](#)

// %% [markdown]
// ### 🌍 The Big Picture**The Documentation Ecosystem**[Overview of your documentation structure]| Category | Purpose ||----------|----------|| [Category 1] | [Description] || [Category 2] | [Description] || [Category 3] | [Description] |

// %% [markdown]
// ### ✨ Living Documentation PrinciplesThis documentation system follows three core principles:**1. Executable Truth**- [Examples specific to your system]**2. Self-Verification**- [Examples specific to your system]**3. Multi-Audience & Multi-Modal**- [Examples specific to your system]

// %% [markdown]
// ### ✅ You've Completed Part 1**What you've learned:**- 📂 [Key point 1]- ✨ [Key point 2]- 🎯 [Key point 3]**Next steps:**- 👤 [By Your Role](#) - Find your learning path- 🎯 [By Your Task](#) - Jump to specific goal- 🔄 [By Workflow](#) - Follow your phase

// %% [markdown]
// ## Part 2: By Your Role**Progress: 2 of [N]** 🔵🔵⚪⚪⚪⚪**Reading time: X minutes**Now that you understand the documentation structure, let's explore navigation based on YOUR role...<!-- action-cards -->- [New Developer](#)- [Experienced Developer](#)- [Architect / Tech Lead](#)- [Project Manager](#)

// %% [markdown]
// ### 👥 New Developer**Required (in order):**1. [doc1.md](path/doc1.md) - Description2. [doc2.md](path/doc2.md) - Description3. [doc3.md](path/doc3.md) - Description**Recommended:**- [doc4.md](path/doc4.md) - Description**Optional (Advanced):**- [doc5.md](path/doc5.md) - Description

// %% [markdown]
// ### ✅ You've Completed Part 2**What you've learned:**- 👥 [N] distinct role-based learning paths- 📚 Essential docs for each role- 🎓 Reading order recommendations**Your role clear?**✓ Great! Bookmark your essential docs and dive in.**Still exploring?**- 🎯 [Building A Simple Component](#) - "I need to build/test X"- 🔄 [Planning Phase](#) - "I'm in X phase"

// %% [markdown]
// ## Part 3: By Your Task**Progress: 3 of [N]** 🔵🔵🔵⚪⚪⚪**Reading time: X minutes**Now that you know your role, let's find documentation by specific tasks...<!-- action-cards -->- [Building Something](#)- [Testing Something](#)- [Debugging Issues](#)- [Creating Content](#)

// %% [markdown]
// ### 🎯 Building [Something]**Required:**- [doc1.md](path/doc1.md) - Description- [doc2.md](path/doc2.md) - Description**Recommended:**- [doc3.md](path/doc3.md) - Description**Pro tip:** [Helpful advice for this task]

// %% [markdown]
// ### ✅ You've Completed Part 3**What you've learned:**- 🎯 [N] common task categories- 📖 Required docs for each task- 💡 Pro tips for complex tasks**Found what you need?**✓ Perfect! Head to those docs and start building.**Want the big picture?**- 🔄 [By Workflow](#) - Planning → Development → Deployment- 💡 [Pro Navigator Tips](#) - Expert tips

// %% [markdown]
// ### Part 4: By Workflow**Progress: 4 of [N]** 🔵🔵🔵🔵⚪⚪**Reading time: X minutes**Individual tasks are important, but workflows show you the complete development journey...<!-- action-cards -->- [Planning Phase](#)- [Development Phase](#)- [Testing Phase](#)- [Documentation Phase](#)- [Deployment Phase](#)

// %% [markdown]
// ### 🔄 Planning Phase**Read these:**1. [doc1.md](path/doc1.md) - Requirements2. [doc2.md](path/doc2.md) - Approach3. [doc3.md](path/doc3.md) - Architecture**Answer:** What? Which approach? Timeline?

// %% [markdown]
// ### ✅ You've Completed Part 4**What you've learned:**- 🔄 [N] development phases- 📚 Essential docs for each phase- 🎯 Phase-specific focus areas**Clear on your phase?**✓ Excellent! Follow those docs through your workflow.**Want more context?**- 📂 [📚Part 5: Core Navigation](#) - Systematic overview- 💡 [💡 Pro Navigator Tips](#) - Navigation strategies

// %% [markdown]
// ### Part 5: Document Categories**Progress: 5 of [N]** 🔵🔵🔵🔵🔵⚪**Reading time: X minutes**Understanding workflows. Sometimes you just need to browse by category...<!-- action-cards -->- [Core Navigation](#)- [Implementation Guides](#)- [Testing And Debugging](#)- [Project Guidelines](#)- [Reference Materials](#)

// %% [markdown]
// ### 📚 Core Navigation**Purpose:** Entry points and cross-references**All docs:**- [index.md](path/index.md) - Central hub- [getting-started.md](path/getting-started.md) - Role-based paths- [flows.md](path/flows.md) - Decision trees

// %% [markdown]
// ### ✅ You've Completed Part 5**What you've learned:**- 📂 All [N] documentation categories- 📊 Complete catalog systematically organized- 🗺️ Category purposes and contents**Found your docs?**✓ Great! You now know the full landscape.**Want expert guidance?**- 💡 [Pro Navigator Tips](#) - [N] navigation tips- 🌍 [Universal Patterns](#) - Apply beyond this project

// %% [markdown]
// ### Part 6: Pro Navigator tips**Progress: 6 of [N]** 🔵🔵🔵🔵🔵🔵**Reading time: X minutes**Master these expert strategies to navigate documentation like a pro...<!-- action-cards -->- [Use Navigation Flows](#)- [Start with Getting Started](#)- [Know the Patterns](#)- [Build Personal Quick Reference](#)

// %% [markdown]
// ### 💡 Tip 1: Use Navigation Flows**Document:** [navigation-flows.md](path/flows.md)Text-based decision trees for:- "Should I use Simple or Complex approach?"- "Which testing method should I use?"- "Which pattern do I need?"Visual flowcharts guide you to the right docs!

// %% [markdown]
// ### ✅ You've Completed Part 6**What you've mastered:**- 🗺️ Navigation flows and decision trees- 📖 Relationship mapping strategies- 🔄 Pattern recognition- 💡 Expert navigation strategies**You're now a documentation power user!****What's next?**- 🌍 [Universal Patterns](#) - Apply these strategies anywhere- 📚 [Remember - This IS Living Documentation](#) - Remember what matters

// %% [markdown]
// ## 🌍 Part 7: Universal Patterns - Beyond This ProjectThe navigation strategies in this system apply to ANY project:**[Example System 1]**- Role-based: [roles]- Task-based: [tasks]- Workflow-based: [phases]- Living docs: [executable examples]**[Example System 2]**- Role-based: [roles]- Task-based: [tasks]- Workflow-based: [phases]- Living docs: [executable examples]**Key insight:** These patterns aren't project-specific - they're universal documentation architecture.

// %% [markdown]
// ### ⚠️ Troubleshooting Navigation Issues**Issue:** "I don't fit cleanly into any of these roles"**Solution:** [Your solution]**Issue:** "This doc references another doc I can't find"**Solution:** [Your solution]**Issue:** "The documentation seems outdated"**Solution:** [Your solution]**Issue:** "There are too many docs - I'm overwhelmed"**Solution:** [Your solution]**Still stuck?** → [getting-started.md](path/getting-started.md)

// %% [markdown]
// ### 💭 Remember - This IS Living Documentation**You don't need to read everything.**You need to know:1. ✅ Where things are (organized by category)2. ✅ How to find them (decision trees + cross-references)3. ✅ When to use them (role + task + workflow navigation)**Meta-Insight:** This notebook demonstrates the very principles it teaches:- **Executable** - Open it in notebook mode- **Multi-audience** - Serves all roles- **Multi-modal navigation** - Browse by role, task, or workflow- **Progressive disclosure** - Summaries → details → deep dives- **Self-documenting** - Shows the pattern by being the patternThis isn't just a navigation guide - it's a working example of living documentation architecture.**Now go build something!** 🚀

// %% [markdown]
// ## 📖 End of Documentation Navigator**Thank you for exploring this guide!**You've completed the full journey through the [Your System Name] documentation system. You now have:✅ Understanding of all [N] documentation categories  ✅ Role-based, task-based, and workflow-based navigation strategies  ✅ Knowledge of [N] pro navigator tips  ✅ Insight into living documentation principles  ✅ Ability to create your own navigation systems**Quick reminders:**- Bookmark [essential-doc-1.md](path/to/doc1.md), [essential-doc-2.md](path/to/doc2.md), and [essential-doc-3.md](path/to/doc3.md)- Use [relevant commands/tools]- Return to this navigator whenever you need guidance**Happy building! 🚀**---*This Documentation Navigator is part of the [Your Project Name] living documentation system.*
