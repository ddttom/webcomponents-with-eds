// %% [markdown]
// # 📝 Educational Notebook Template
//
// **About this template:** This template uses pure markdown for fast authoring. Perfect for educational notebooks with runnable code cells.
//
// **Auto-wrapping:** When displayed in **notebook mode** (`| IPynb Viewer (notebook) |`), markdown cells are automatically wrapped with beautiful styling:
// - First cell with `#` heading → Hero cell
// - Early cells with `##` → Intro cards (thick border)
// - Short cells (≤3 lines) → Transition cards
// - Other cells → Content cards (thin border)
//
// **Hybrid approach:** Mix pure markdown with custom HTML for specific cells needing special styling.
//
// **Use this for:**
// - Interactive tutorials with runnable code
// - Step-by-step learning experiences
// - Educational content with demonstrations
// - Fast authoring (90% less code than manual HTML)

// %% [markdown]
// # 📚 Your Educational Tutorial Title
//
// **What you'll learn:** Brief description of the learning objectives.
//
// **Prerequisites:** What you should know before starting.
//
// **Duration:** Estimated time to complete.
//
// <!-- action-cards -->
//
// - [Introduction](#)
// - [Basic Concepts](#)
// - [Hands-On Practice](#)
// - [Advanced Topics](#)

// %% [markdown]
// ## 📋 Table of Contents
//
// - [Part 1: Introduction](#part-1-introduction)
// - [Part 2: Basic Concepts](#part-2-basic-concepts)
// - [Part 3: Hands-On Practice](#part-3-hands-on-practice)
// - [Part 4: Advanced Topics](#part-4-advanced-topics)
// - [Conclusion](#conclusion)

// %% [markdown]
// ## Part 1: Introduction
//
// Explain what this tutorial covers and why it's important.
//
// ### Learning Objectives
//
// By the end of this tutorial, you will be able to:
// - Objective 1
// - Objective 2
// - Objective 3

// %% [markdown]
// ## Part 2: Basic Concepts
//
// Introduce fundamental concepts with explanations.
//
// ### Concept 1: Understanding the Basics
//
// Explain the first concept clearly.

// %%
// Example demonstrating Concept 1
// Try modifying the values and running this cell!

const example = 'Hello, learner!';
console.log(example);

return example;

// %% [markdown]
// **What just happened?**
//
// Explain the code execution and results.

// %% [markdown]
// ### Concept 2: Building on the Basics
//
// Introduce the next concept with more complexity.

// %%
// Example demonstrating Concept 2
// Feel free to experiment with this code!

const numbers = [1, 2, 3, 4, 5];
const doubled = numbers.map(n => n * 2);

console.log('Original:', numbers);
console.log('Doubled:', doubled);

return doubled;

// %% [markdown]
// ## Part 3: Hands-On Practice
//
// ### Exercise 1
//
// **Task:** Describe what the learner should do.
//
// **Hint:** Provide helpful guidance.

// %%
// Your code here
// Complete the exercise based on the instructions above

// %% [markdown]
// ### Exercise 2
//
// **Task:** Another practice exercise.
//
// **Expected output:** What the learner should see.

// %%
// Your solution here

// %% [markdown]
// ## Part 4: Advanced Topics
//
// Introduce more advanced concepts for learners who want to go deeper.
//
// ### Advanced Pattern 1
//
// Explain an advanced technique or pattern.

// %%
// Advanced example
// This demonstrates a more complex pattern

const advancedPattern = (data) => {
  return data
    .filter(item => item > 0)
    .map(item => item * 2)
    .reduce((sum, item) => sum + item, 0);
};

const result = advancedPattern([1, -2, 3, -4, 5]);
console.log('Result:', result);

return result;

// %% [markdown]
// ---
//
// Ready for the conclusion?

// %% [markdown]
// ## Conclusion
//
// ### What You Learned
//
// Recap the main concepts covered:
// - Key learning 1
// - Key learning 2
// - Key learning 3
//
// ### Next Steps
//
// Suggest where learners can go from here:
// - Additional resources
// - Related tutorials
// - Practice projects
//
// ### Further Reading
//
// - [Resource 1](url)
// - [Resource 2](url)
// - [Resource 3](url)

// %% [markdown]
// <!-- Example: Custom styled cell for special emphasis -->
// <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); border-radius: 12px; padding: 32px; margin: 0; text-align: center; color: white;">
//
// <h2 style="font-size: 32px; font-weight: 800; margin: 0;">🎉 Congratulations!</h2>
//
// <p style="font-size: 18px; margin: 16px 0;">You've completed the tutorial!</p>
//
// </div>
